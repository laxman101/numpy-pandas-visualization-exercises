# %%
#  'hnvidduckkqxwymbimkccexbkmqygkxoyndmcxnwqarhyffsjpsrabtjzsypmzadfavyrnndndvswreauxovncxtwzpwejilzjrmmbbgbyxvjtewqthafnbkqplarokkyydtubbmnexoypulzwfhqvckdpqtpoppzqrmcvhhpwgjwupgzhiofohawytlsiyecuproguy'

# %%
# 1. Which letter occurs the most frequently in the letters Series?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
letters = list('hnvidduckkqxwymbimkccexbkmqygkxoyndmcxnwqarhyffsjpsrabtjzsypmzadfavyrnndndvswreauxovncxtwzpwejilzjrmmbbgbyxvjtewqthafnbkqplarokkyydtubbmnexoypulzwfhqvckdpqtpoppzqrmcvhhpwgjwupgzhiofohawytlsiyecuproguy')
letters
# Out:
# ['h',
#  'n',
#  'v',
#  'i',
#  'd',
#  'd',
#  'u',
#  'c',
#  'k',
#  'k',
#  'q',
#  'x',
#  'w',
#  'y',
#  'm',
#  'b',
#  'i',
#  'm',
#  'k',
#  'c',
#  'c',
#  'e',
#  'x',
#  'b',
#  'k',
#  'm',
#  'q',
#  'y',
#  'g',
#  'k',
#  'x',
#  'o',
#  'y',
#  'n',
#  'd',
#  'm',
#  'c',
#  'x',
#  'n',
#  'w',
#  'q',
#  'a',
#  'r',
#  'h',
#  'y',
#  'f',
#  'f',
#  's',
#  'j',
#  'p',
#  's',
#  'r',
#  'a',
#  'b',
#  't',
#  'j',
#  'z',
#  's',
#  'y',
#  'p',
#  'm',
#  'z',
#  'a',
#  'd',
#  'f',
#  'a',
#  'v',
#  'y',
#  'r',
#  'n',
#  'n',
#  'd',
#  'n',
#  'd',
#  'v',
#  's',
#  'w',
#  'r',
#  'e',
#  'a',
#  'u',
#  'x',
#  'o',
#  'v',
#  'n',
#  'c',
#  'x',
#  't',
#  'w',
#  'z',
#  'p',
#  'w',
#  'e',
#  'j',
#  'i',
#  'l',
#  'z',
#  'j',
#  'r',
#  'm',
#  'm',
#  'b',
#  'b',
#  'g',
#  'b',
#  'y',
#  'x',
#  'v',
#  'j',
#  't',
#  'e',
#  'w',
#  'q',
#  't',
#  'h',
#  'a',
#  'f',
#  'n',
#  'b',
#  'k',
#  'q',
#  'p',
#  'l',
#  'a',
#  'r',
#  'o',
#  'k',
#  'k',
#  'y',
#  'y',
#  'd',
#  't',
#  'u',
#  'b',
#  'b',
#  'm',
#  'n',
#  'e',
#  'x',
#  'o',
#  'y',
#  'p',
#  'u',
#  'l',
#  'z',
#  'w',
#  'f',
#  'h',
#  'q',
#  'v',
#  'c',
#  'k',
#  'd',
#  'p',
#  'q',
#  't',
#  'p',
#  'o',
#  'p',
#  'p',
#  'z',
#  'q',
#  'r',
#  'm',
#  'c',
#  'v',
#  'h',
#  'h',
#  'p',
#  'w',
#  'g',
#  'j',
#  'w',
#  'u',
#  'p',
#  'g',
#  'z',
#  'h',
#  'i',
#  'o',
#  'f',
#  'o',
#  'h',
#  'a',
#  'w',
#  'y',
#  't',
#  'l',
#  's',
#  'i',
#  'y',
#  'e',
#  'c',
#  'u',
#  'p',
#  'r',
#  'o',
#  'g',
#  'u',
#  'y']

# %%
letters_series = pd.Series(['h','n','v','i','d','d','u','c','k','k','q','x','w','y','m','b','i','m','k','c','c','e','x','b','k','m','q','y','g','k','x','o','y','n','d','m','c','x','n','w','q','a','r','h','y','f','f','s','j','p','s','r','a','b','t','j','z','s','y','p','m','z','a','d','f','a','v','y','r','n','n','d','n','d','v','s','w','r','e','a','u','x','o','v','n','c','x','t','w','z','p','w','e','j','i','l','z','j','r','m','m','b','b','g','b','y','x','v','j','t','e','w','q','t','h','a','f','n','b','k','q','p','l','a','r','o','k','k','y','y','d','t','u','b','b','m','n','e','x','o','y','p','u','l','z','w','f','h','q','v','c','k','d','p','q','t','p','o','p','p','z','q','r','m','c','v','h','h','p','w','g','j','w','u','p','g','z','h','i','o','f','o','h','a','w','y','t','l','s','i','y','e','c','u','p','r','o','g','u','y']).value_counts()

# %%
type(letters_series)
# Out:
# pandas.core.series.Series

# %%
letters_series.values
# Out:
# array([13, 12, 10,  9,  9,  9,  9,  8,  8,  8,  8,  8,  8,  8,  8,  7,  7,
#         7,  7,  6,  6,  6,  5,  5,  5,  4])

# %%
letters_series
# Out:
# y    13
# p    12
# w    10
# n     9
# k     9
# m     9
# b     9
# h     8
# q     8
# a     8
# o     8
# x     8
# d     8
# c     8
# r     8
# z     7
# t     7
# u     7
# v     7
# f     6
# j     6
# e     6
# s     5
# g     5
# i     5
# l     4
# dtype: int64

# %%
pd.Series(['h','n','v','i','d','d','u','c','k','k','q','x','w','y','m','b','i','m','k','c','c','e','x','b','k','m','q','y','g','k','x','o','y','n','d','m','c','x','n','w','q','a','r','h','y','f','f','s','j','p','s','r','a','b','t','j','z','s','y','p','m','z','a','d','f','a','v','y','r','n','n','d','n','d','v','s','w','r','e','a','u','x','o','v','n','c','x','t','w','z','p','w','e','j','i','l','z','j','r','m','m','b','b','g','b','y','x','v','j','t','e','w','q','t','h','a','f','n','b','k','q','p','l','a','r','o','k','k','y','y','d','t','u','b','b','m','n','e','x','o','y','p','u','l','z','w','f','h','q','v','c','k','d','p','q','t','p','o','p','p','z','q','r','m','c','v','h','h','p','w','g','j','w','u','p','g','z','h','i','o','f','o','h','a','w','y','t','l','s','i','y','e','c','u','p','r','o','g','u','y']).value_counts()
# Out:
# y    13
# p    12
# w    10
# n     9
# k     9
# m     9
# b     9
# h     8
# q     8
# a     8
# o     8
# x     8
# d     8
# c     8
# r     8
# z     7
# t     7
# u     7
# v     7
# f     6
# j     6
# e     6
# s     5
# g     5
# i     5
# l     4
# dtype: int64

# %%
vowels = list('aeiou')
vowels
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
letters_series = pd.Series(vowels)
letters_series
# Out:
# 0    a
# 1    e
# 2    i
# 3    o
# 4    u
# dtype: object

# %%
letters_series[letters_series.isin(vowels)]
# Out:
# 0    a
# 1    e
# 2    i
# 3    o
# 4    u
# dtype: object

# %%
# letters_series.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f1d018eaff23> in <module>
# ----> 1 letters_series.value_count()
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
letter = list('hnvidduckkqxwymbimkccexbkmqygkxoyndmcxnwqarhyffsjpsrabtjzsypmzadfavyrnndndvswreauxovncxtwzpwejilzjrmmbbgbyxvjtewqthafnbkqplarokkyydtubbmnexoypulzwfhqvckdpqtpoppzqrmcvhhpwgjwupgzhiofohawytlsiyecuproguy')
letter
# Out:
# ['h',
#  'n',
#  'v',
#  'i',
#  'd',
#  'd',
#  'u',
#  'c',
#  'k',
#  'k',
#  'q',
#  'x',
#  'w',
#  'y',
#  'm',
#  'b',
#  'i',
#  'm',
#  'k',
#  'c',
#  'c',
#  'e',
#  'x',
#  'b',
#  'k',
#  'm',
#  'q',
#  'y',
#  'g',
#  'k',
#  'x',
#  'o',
#  'y',
#  'n',
#  'd',
#  'm',
#  'c',
#  'x',
#  'n',
#  'w',
#  'q',
#  'a',
#  'r',
#  'h',
#  'y',
#  'f',
#  'f',
#  's',
#  'j',
#  'p',
#  's',
#  'r',
#  'a',
#  'b',
#  't',
#  'j',
#  'z',
#  's',
#  'y',
#  'p',
#  'm',
#  'z',
#  'a',
#  'd',
#  'f',
#  'a',
#  'v',
#  'y',
#  'r',
#  'n',
#  'n',
#  'd',
#  'n',
#  'd',
#  'v',
#  's',
#  'w',
#  'r',
#  'e',
#  'a',
#  'u',
#  'x',
#  'o',
#  'v',
#  'n',
#  'c',
#  'x',
#  't',
#  'w',
#  'z',
#  'p',
#  'w',
#  'e',
#  'j',
#  'i',
#  'l',
#  'z',
#  'j',
#  'r',
#  'm',
#  'm',
#  'b',
#  'b',
#  'g',
#  'b',
#  'y',
#  'x',
#  'v',
#  'j',
#  't',
#  'e',
#  'w',
#  'q',
#  't',
#  'h',
#  'a',
#  'f',
#  'n',
#  'b',
#  'k',
#  'q',
#  'p',
#  'l',
#  'a',
#  'r',
#  'o',
#  'k',
#  'k',
#  'y',
#  'y',
#  'd',
#  't',
#  'u',
#  'b',
#  'b',
#  'm',
#  'n',
#  'e',
#  'x',
#  'o',
#  'y',
#  'p',
#  'u',
#  'l',
#  'z',
#  'w',
#  'f',
#  'h',
#  'q',
#  'v',
#  'c',
#  'k',
#  'd',
#  'p',
#  'q',
#  't',
#  'p',
#  'o',
#  'p',
#  'p',
#  'z',
#  'q',
#  'r',
#  'm',
#  'c',
#  'v',
#  'h',
#  'h',
#  'p',
#  'w',
#  'g',
#  'j',
#  'w',
#  'u',
#  'p',
#  'g',
#  'z',
#  'h',
#  'i',
#  'o',
#  'f',
#  'o',
#  'h',
#  'a',
#  'w',
#  'y',
#  't',
#  'l',
#  's',
#  'i',
#  'y',
#  'e',
#  'c',
#  'u',
#  'p',
#  'r',
#  'o',
#  'g',
#  'u',
#  'y']
